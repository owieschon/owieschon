# %% [markdown]
# # Feature-time leakage, made visible
#
# This notebook is a thin wrapper over the standard-library experiment in `run_demo.py`.

# %%
from run_demo import run_experiment
result = run_experiment(seed=20260710)
result

# %% [markdown]
# The near-perfect leaky score is invalid: it depends on post-cutoff peer outcomes. The cutoff-safe score is deliberately uninformative, and a future-label perturbation changes only the leaky feature.
